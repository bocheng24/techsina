# %%
from selenium import webdriver
import pandas as pd
import time

# %%
import bs4

# %%
import requests

# %%
page = requests.get('https://tech.sina.com.cn/')

# %%
html = bs4.BeautifulSoup(page.content)

# %%
html.findAll('li')
# Out:
# [<li class="sina15-nav-list-first"><a href="http://www.sina.com.cn/">新浪首页</a></li>,
#  <li><a href="http://news.sina.com.cn/">新闻</a></li>,
#  <li><a href="http://sports.sina.com.cn/">体育</a></li>,
#  <li><a href="http://finance.sina.com.cn/">财经</a></li>,
#  <li><a href="http://ent.sina.com.cn/">娱乐</a></li>,
#  <li><a href="http://tech.sina.com.cn/">科技</a></li>,
#  <li><a href="http://blog.sina.com.cn/">博客</a></li>,
#  <li><a href="http://photo.sina.com.cn/">图片</a></li>,
#  <li><a href="http://zhuanlan.sina.com.cn/">专栏</a></li>,
#  <li class="sina15-nav-list-last"><a class="sina15-more" data-action="dropdown" data-target="more" href="#">更多<i class="sina15-icon sina15-icon-arrows-a"></i></a></li>,
#  <li><a href="http://auto.sina.com.cn/">汽车</a><a href="http://edu.sina.com.cn/">教育</a><a href="http://fashion.sina.com.cn/">时尚</a><a href="http://eladies.sina.com.cn/">女性</a><a href="http://astro.sina.com.cn/">星座</a><a href="http://health.sina.com.cn/">健康</a></li>,
# ...

# %%
from webdriver_manager.chrome import ChromeDriverManager

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# [WDM] - Current google-chrome version is 84.0.4147
# [WDM] - Get LATEST driver version for 84.0.4147
# [WDM] - There is no [mac64] chromedriver for browser 84.0.4147 in cache
# [WDM] - Get LATEST driver version for 84.0.4147
# [WDM] - Trying to download new driver from http://chromedriver.storage.googleapis.com/84.0.4147.30/chromedriver_mac64.zip
# [WDM] - Driver has been saved in cache [/Users/bocheng/.wdm/drivers/chromedriver/mac64/84.0.4147.30]

# %%
browser = webdriver.Chrome('./chromedriver')
browser.get('https://tech.sina.com.cn/')
browser.maximize_window()

# %%
menu = browser.find_elements_by_class_name('tyfeed-tab-i')

# %%
menus = menu[1:].append(menu[0])

# %%
menus

# %%
menu[1].click()

# %%
menu[1:]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="67ebc87d824f9279d4aa91882f29cf1b", element="89fdd513-4621-426b-badb-c57f0bb5ece6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="67ebc87d824f9279d4aa91882f29cf1b", element="652788e7-0108-485a-8ac1-abf39c6c2b86")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="67ebc87d824f9279d4aa91882f29cf1b", element="b6236461-5b8d-4705-a70c-6d246d932934")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="67ebc87d824f9279d4aa91882f29cf1b", element="2b4410ea-1c62-488b-9c10-a05af78b1842")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="67ebc87d824f9279d4aa91882f29cf1b", element="0df5ad8d-c59e-4adf-8b56-939a11156874")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="67ebc87d824f9279d4aa91882f29cf1b", element="27c36ebe-ed7e-42b5-ae5b-eeab323001b5")>,
# ...

# %%
slider_items[0].find_element_by_tag_name('span').text
# Out:
# ''

# %%
cards = browser.find_element_by_class_name('tech-mid').find_elements_by_class_name('ty-card')

# %%
len(cards)
# Out:
# 20

# %%
cards[0].find_element_by_tag_name('img').get_attribute('src')
# Out:
# 'https://k.sinaimg.cn/n/tech/transform/667/w400h267/20200822/3e6e-iyaiihm1774597.jpg/w300h200f1t0l0q100syf.jpg'

# %%
browser.execute_script('window.scrollTo(0, document.body.scrollHeight/2)')

# %%
browser.find_element_by_id('j_cardlist').text
# Out:
# '一箭三星成功！长二丁火箭2020年连续7次成功发射\n今天 11:43一箭三星\n28\n企业微信海外版悄然改名，或与美国禁令有关\n今天 11:44微信美国禁令\n100\n彭蕾、张勇、武卫3人退出蚂蚁集团董事\n今天 10:45蚂蚁集团张勇彭蕾\n21\n字节跳动正式起诉特朗普及美国政府 并准备美国业务的"关停预案"\n今天 10:09字节跳动特朗普禁令起诉\n621\n首个功能正常的微型人类心脏模型诞生，可用于研究心血管疾病\n今天 09:22微型心脏\n8\n关节磨损还有救吗？斯坦福科学家开发软骨再生新方法！\n今天 09:18关节软骨\n3\n人类给外星人发信的望远镜，被一根钢缆砸坏了\n今天 09:14射电望远镜地外文明\n36\n如果寄生虫灭绝了,会发生什么?用10年时间拯救全球寄生虫的计划\n今天 09:10寄生虫生物多样性\n18\n七夕节如何用iPhone记录精彩回忆？这份攻略你要收好\n8月22日 18:08iPhone拍照\n24\n因为它，一次能盖两碗泡面的可折叠kindle也许不远了\n今天 06:37kindle墨水屏\n12\n"随"你跑—R2 REAL RUN信念全地形跑鞋轻体验\n今天 11:31跑鞋\n18\n如何让孩子放下手机，爱上学习？这位妈妈用1招搞定\n总结了拼多多12种常见套路后 我们发现“兔费≠免费 ”\n今天 09:04拼多多套路\n4306\n拥有XX染色体，却发育出男性性器官：一个基因突变改变人类性别\n今天 09:02基因\n7\nTikTok计划最早下周起诉特朗普政府\n今天 07:32美国政府特朗普TikTok\n18996\n美国“羚羊彩穴”鬼斧神工，摄影爱好者必去的朝圣之地5张\n今天 08:48羚羊彩穴\n外媒：iPhone12将在10月正式发布\n8月22日 20:50iPhone 12苹果\n1888\n当猫头鹰偶遇灰松鼠，实力演绎“我自岿然不动”5张\n今天 08:25猫头鹰松鼠\n这才是猛男的专属必备神器：KICA K2筋膜枪\n今天 13:44\n7\n推荐这道懒人饭，简单一焖香糯入味，全家爱吃\n今天 13:47菜谱香糯羊肉\n6\n低延迟，高颜值，南卡Lite耳机入手体验！\n今天 14:01入耳式无线蓝牙耳机\n5\n王兴谈投资理想汽车：很多人低估了创始人李想\n8月22日 1
# ...

# %%
load.text
# Out:
# ''

# %%
load.click()

# %%
browser.quit()

# %%
menu[4].click()

# %%
browser.execute_script('window.scrollTo(0, document.body.scrollHeight)')

# %%
browser.execute_script('window.scrollTo(0, -200)')

# %%
load = browser.find_element_by_class_name('cardlist-a__more')

while load.text != '已经到底啦~':
    browser.execute_script('window.scrollTo(0, document.body.scrollHeight)')
        
    time.sleep(1)
    load = browser.find_element_by_class_name('cardlist-a__more')
    
    if load.text == '点击查看更多':
        browser.find_element_by_class_name('f_app_close').click()
        browser.execute_script('window.scrollTo(0, -200)')
        load.click()
        browser.execute_script('window.scrollTo(0, document.body.scrollHeight / 2)')

# %%
browser.find_element_by_id('j_cardlist').text
# Out:
# '外媒：iPhone12将在10月正式发布\n今天 20:50iPhone 12苹果\n904\n王兴谈投资理想汽车：很多人低估了创始人李想\n今天 14:07王兴理想\n217\nFacebook首席营销官在任职两年之后离职\n今天 14:01Facebook首席营销官\n土耳其科尼亚一湖泊变粉色，满满治愈少女心！6张\n今天 12:14土耳其\n3\nFacebook质询FTC：如何避免另一家“剑桥分析”的出现\n今天 10:56FacebookFTC\n7\n我超凶的！围观动物发威怒吼表情包7张\n今天 12:11动物\n4\n苹果：Epic在App Store抽成上寻求特殊“单边”协议\n今天 10:18苹果堡垒之夜Epic\n知情人士：Alphabet曾考虑收购TikTok的少量股份\n今天 10:10AlphabetTikTok\n27\n[tiu的观影记录]了解历史，不负《八佰》\n今天 16:01影评八佰管虎\n35\niPhone12 Pro Max配置清单曝光 顶级配置估计要卖爆\n今天 06:30iPhone苹果\n321\n七夕情人节怎么过？拯救直男的15份约会攻略\n今天 17:30\n15\n淋巴竟然给癌细胞发“免死金牌”！\n今天 09:37淋巴癌细胞\n23\n朋友圈骂人该不该被处罚？|围炉说\n今天 09:35朋友圈处罚\n3255\n连生啤、熟啤、鲜啤、精酿都分不清楚，还喝什么啤酒！\n今天 09:26啤酒\n38\nOMG！54.4°C！近百年来地球最高气温惊现这里？！\n今天 09:16高温极端天气\n8\n3天1.1万次雷击，加州山火蔓延！全球变暖是帮凶\n今天 09:14加州山火\n11\n鼻子里喷一下就有望产生保护？新型新冠疫苗彰显积极结果\n今天 09:11新冠疫苗新冠肺炎\n5\n泰捷WEBOX WE40升级版真实使用感受\n今天 16:31相机电视盒子内存\n17\n颜值超经典，音质看齐一线大厂！南卡lite评测\n今天 17:22无线蓝牙耳机\n11\n“浪姐”抖音直播翻车：20万坑位费成交仅6000多元\n今天 06:49浪姐抖音直播\n253\n三大运营商半年报出炉 5G用户数年底将超1亿\n今天 08:14运营商5G\n71\n印度最新民调：近半数印度人支持中企在印经营\n今天 07:36印度App\n
# ...

# %%
slider_items = browser.find_elements_by_class_name('slider-item')

# %%
slider_items[0].find_element_by_tag_name('a').get_attribute('href')
# Out:
# 'https://tech.sina.com.cn/i/2020-08-23/doc-iivhuipp0155093.shtml'

# %%
slider_items[0].find_element_by_tag_name('a').find_element_by_tag_name('img').get_attribute('src')
# Out:
# 'https://n.sinaimg.cn/tech/transform/160/w640h320/20200823/3679-iyaiihm2617430.jpg'

# %%
span = slider_items[1].find_element_by_tag_name('a').find_element_by_tag_name('span')

# %%
span.text
# Out:
# ''

# %%
page = requests.get(slider_items[0].find_element_by_tag_name('a').get_attribute('href'))
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-186-9b292fe3979e> in <module>
# ----> 1 page = requests.get(slider_items[0].find_element_by_tag_name('a').get_attribute('href'))
#
# /opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webelement.py in find_element_by_tag_name(self, name)
#     303             element = element.find_element_by_tag_name('h1')
#     304         """
# --> 305         return self.find_element(by=By.TAG_NAME, value=name)
#     306
#     307     def find_elements_by_tag_name(self, name):
#
# /opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webelement.py in find_element(self, by, value)
#     657
#     658         return self._execute(Command.FIND_CHILD_ELEMENT,
# --> 659                              {"using": by, "value": value})['value']
#     660
# ...

# %%
html = bs4.BeautifulSoup(page.content, 'lxml')

# %%
html.find('h1').text
# Out:
# '总结了拼多多12种常见套路后，我们发现“兔费≠免费 ”|诉说'

# %%
html.find('span', {'class': 'date'}).text
# Out:
# '2020年08月23日 09:04'

# %%
page
# Out:
# <Response [200]>

# %%
page.content
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x08\x06\x06\x07\x06\x05\x08\x07\x07\x07\t\t\x08\n\x0c\x14\r\x0c\x0b\x0b\x0c\x19\x12\x13\x0f\x14\x1d\x1a\x1f\x1e\x1d\x1a\x1c\x1c $.\' ",#\x1c\x1c(7),01444\x1f\'9=82<.342\xff\xdb\x00C\x01\t\t\t\x0c\x0b\x0c\x18\r\r\x182!\x1c!22222222222222222222222222222222222222222222222222\xff\xc0\x00\x11\x08\x01@\x02\x80\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n\x16\x17\x18\x19\x1a%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\x83\x84\x85\x86\x87\x88\x89\x8a\x92\x93\x94\x95\x96\x97\x98\x99\x9a\xa2\xa3\xa4\xa5\xa6\xa7\xa8\xa9\xaa\xb2\xb3\xb4\xb5\xb6\xb7\xb8\xb9\xba\xc2\xc3\xc4\xc5\xc6\xc7\xc8\xc9\xca\xd2\xd3\x
# ...
